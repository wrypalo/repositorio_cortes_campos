# %%
import pandas as pd
import altair as alt

# Opciones de Altair para datasets grandes
alt.data_transformers.disable_max_rows()

# Cargar datos
df = pd.read_csv("Recopilatorio Datos Festival de viña del mar (limpia).csv", sep=";")

# Limpieza básica, acá sacamos la columna de índices, pueden hacerlo con excel también antes de guardar, esto es solo un ejemplo del proceso posible
df = df.rename(columns={"Unnamed: 0":"idx"})
if "idx" in df.columns:
    df = df.drop(columns=["idx"])

# Echar un vistazo
df.head(10)
# Out:
#             Artista     Año Género F/M/Mixto Grupo/solista     Género musical  \
# 0     Marc Anthony   2025.0           Hombre       Solista              Salsa
# 1           Bacilos  2025.0           Hombre         Grupo         Pop Latino
# 2  Myriam Hernandez  2025.0            Mujer      Solista    Balada Romántica
# 3            Ha*Ash  2025.0            Mujer           Duo              Pop
# 4            Morat   2025.0           Hombre         Grupo        Pop  Latino
# 5   Sebastian Yatra  2025.0           Hombre       Solista        Pop Latino
# 6      Carlos Vives  2025.0           Hombre       Solista       Pop tropical
# 7        Carín Leon  2025.0           Hombre       Solista  Regional Mexicana
# 8           Incubus  2025.0            Mixto         Grupo   Rock Alternativo
# 9          The Cult  2025.0           Hombre         Grupo          Hard rock
#
#                   Nacionalidad
# 0  Estados Unidos/ Puerto Rico
# 1               Estados Unidos
# 2                        Chile
# 3                       México
# 4                     Colombia
# 5                     Colombia
# 6                     Colombia
# 7                       México
# 8                         EEUU
# 9                  Reino Unido
